# %%
from openai import OpenAI, RateLimitError, APITimeoutError
from tqdm import tqdm
import tiktoken
import concurrent
import time
import json
from pprint import pprint
openai_client = OpenAI(api_key=open("api_key").read().strip())
def save_json(data, filename):
    with open (filename, 'w') as f:
        json.dump(data, f, indent=4, ensure_ascii=False)

def request_gpt(
    client, messages, model="gpt-4o-mini", temperature=0.5, format=None, seed=None
):
    with open("request_log.txt", "a", encoding="utf-8") as f:
        f.write(f"model: {model}, temperature: {temperature}, format: {format}\n")
        f.write(json.dumps(messages, ensure_ascii=False) + "\n")
        f.write("=====================================\n")
    try:
        if format == "json":
            response = client.chat.completions.create(
                    model=model,
                    messages=messages,
                    response_format={"type": "json_object"},
                    temperature=temperature,
                    seed=seed,
                )
            

        else:
            response = client.chat.completions.create(
                model=model, messages=messages, temperature=temperature, seed=seed
            )
        return response.choices[0].message.content
    except RateLimitError as e:
        print("RateLimitError")
        print(e)
        time.sleep(5)
        return request_gpt(client, messages, model, temperature, format)
    except APITimeoutError as e:
        print("APITimeoutError")
        print(messages)
        time.sleep(5)
        return request_gpt(client, messages, model, temperature, format)

def multithread_prompts(
    client,
    prompts,
    model="gpt-4o-mini",
    temperature=0.5,
    format=None,
    seed=None,
):
    l = len(prompts)
    # results = np.zeros(l)
    with tqdm(total=l) as pbar:
        executor = concurrent.futures.ThreadPoolExecutor(max_workers=100)
        futures = [
            executor.submit(
                request_gpt, client, prompt, model, temperature, format, seed
            )
            for prompt in prompts
        ]
        for _ in concurrent.futures.as_completed(futures):
            pbar.update(1)
    concurrent.futures.wait(futures)
    return [future.result() for future in futures]

def read_jsonl(filename):
    with open(filename, "r") as f:
        return [json.loads(line) for line in f]
def flatten(xss):
    return [x for xs in xss for x in xs]

# %%
# %pip install pandas

# %%
import random
redfm_test_set = read_jsonl("REDFM/data/test.en.jsonl")
redfm_dev_set = read_jsonl("REDFM/data/dev.en.jsonl")
all_relations = json.load(open("REDFM/data/all_relations.json"))
all_relation_indices = { v: k for k, v in all_relations.items() }
# note: subject and object are exact matches in the text, predicate is one of the relations in all_relations and may not appear in the text
few_shot_examples = [{
    "sentence": t['text'],
    "entities": [
        {
            "name": e['surfaceform'],
            "type": e['type']
        } 
        for e in t['entities']
    ],
    "triplets": [
        {
            "subject": r['subject']['surfaceform'],
            "predicate": int(all_relation_indices[r['predicate']['surfaceform']]),
            "object": r["object"]["surfaceform"]
        } for r in t['relations']
    ]
} for t in random.sample(redfm_test_set, 10)]

# %% [markdown]
# ## single prompt

# %%
all_relations_str = "\n".join([f"{i}: {r}" for i, r in all_relations.items()])
system_prompt = {
    "role": "system",
    "content": """You are a knowledge graph constructor. 
        You will be given a sentence, you need to extract a triplet of the form (subject, predicate, object) from the sentence.
        The predicate should be one of the following relations:
        {all_relations_str}
        Reply with the following JSON format:
        {{
            triplets: [
                {{
                    subject: (string),
                    predicate: (int, index of the relation in the list),
                    object: (string)
                }}
            ]
        }}
    """.format(all_relations_str=all_relations_str)
}
user_prompt = lambda sentence: {
    "role": "user",
    "content": f"""Sentence: {sentence}"""
}
few_shot_prompts = flatten([
    [
        {
            "role": "user",
            "content": example['sentence'], 
        },
        {
            "role": "assistant",
            "content": json.dumps({
                "triplets": example['triplets']
            }),
        }
    ]
    for example in few_shot_examples
])

# %%
prompts = [[system_prompt] + few_shot_prompts + [user_prompt(test_sample['text'])] for test_sample in redfm_test_set]
prompts = prompts
answers = [
    [
        {
            "subject": r['subject']['surfaceform'],
            "predicate": int(all_relation_indices[r['predicate']['surfaceform']]),
            "object": r["object"]["surfaceform"]
        }
        for r in test_sample['relations']
    ]
    for test_sample in redfm_test_set]
responses = multithread_prompts(openai_client, prompts, model="gpt-4o-mini", temperature=0, format="json")
responses = [json.loads(response)['triplets'] for response in responses]
save_json(responses, "single_prompt_responses.json")
# Out:
# 100%|██████████| 446/446 [00:12<00:00, 37.06it/s]

# %% [markdown]
# ## Decomposed prompt

# %%
# entity extraction
system_prompt = {
    "role": "system",
    "content": """You are an entity extractor. You will be given a sentence, you need to extract all the entities from the sentence. 
    The entities have to match exactly with the text.
    Reply with the following JSON format: 
        {{
            entities: [(string)]
        }}
    """
}
user_prompt = lambda sentence: {
    "role": "user",
    "content": f"""Sentence: {sentence}"""
}
few_shot_prompts = flatten([
    [
        {
            "role": "user",
            "content": example['sentence'], 
        },
        {
            "role": "assistant",
            "content": json.dumps({
                "entities": example['entities']
            }),
        }
    ]
    for example in few_shot_examples
])
prompts = [[system_prompt] + few_shot_prompts + [user_prompt(test_sample['text'])] for test_sample in redfm_test_set]
prompts = prompts
answers = [
    [
        e['surfaceform']
        for e in test_sample['entities']
    ]
    for test_sample in redfm_test_set]
responses = multithread_prompts(openai_client, prompts, model="gpt-4o-mini", temperature=0, format="json")
responses = [json.loads(response)['entities'] for response in responses]
save_json(responses, "decomposed_prompt_entities.json")
# Out:
# 100%|██████████| 446/446 [00:15<00:00, 27.96it/s]

# %%
# relation extraction
all_relations_str = "\n".join([f"{i}: {r}" for i, r in all_relations.items()])
system_prompt = {
    "role": "system",
    "content": """You are a relation extractor
        You will be given a sentence and a list of entities appearing in the sentence.
        You need to assign a relation between any two entities in the form of a triplet (subject, predicate, object).
        The relation should be one of the following relations:
        {all_relations_str}
        Reply with the following JSON format:
        {{
            triplets: [
                {{
                    subject: (string),
                    predicate: (int, index of the relation in the list),
                    object: (string)
                }}
            ]
        }}
    """.format(all_relations_str=all_relations_str)
}
user_prompt = lambda sentence, entities: {
    "role": "user",
    "content": f"""Sentence: {sentence} \n Entities: {entities}"""
}
few_shot_prompts = flatten([
    [
        {
            "role": "user",
            "content": f"Sentence: {example['sentence']} \n Entities: {example['entities']}", 
        },
        {
            "role": "assistant",
            "content": json.dumps({
                "triplets": example['triplets']
            }),
        }
    ]
    for example in few_shot_examples
])
entities = json.load(open("decomposed_prompt_entities.json"))
prompts = []
for test_sample, entity_responses in zip(redfm_test_set, entities):
   # for each combination of entity pairs
    prompts.append([system_prompt] + few_shot_prompts + [user_prompt(test_sample['text'], entity_responses)])
prompts = prompts
answers = [
    [
        {
            "subject": r['subject']['surfaceform'],
            "predicate": int(all_relation_indices[r['predicate']['surfaceform']]),
            "object": r["object"]["surfaceform"]
        }
        for r in test_sample['relations']
    ]
    for test_sample in redfm_test_set]
responses = multithread_prompts(openai_client, prompts, model="gpt-4o-mini", temperature=0, format="json")
responses = [json.loads(response)['triplets'] for response in responses]
save_json(responses, "decomposed_prompt_relations.json")
# Out:
# 100%|██████████| 446/446 [00:13<00:00, 32.04it/s]

# %% [markdown]
# ## Decomposed Prompt -- v2

# %%
# entity extraction
# entity_types = ['EVE', 'ORG', 'NUMBER', 'DATE', 'TIME', 'PER', 'CEL', 'Concept', 'MEDIA', 'LOC', 'MISC', 'UNK']
# entity_types = ['event', 'organization', 'number', 'date', 'time', 'person', 'celestial', 'concept', 'media', 'location', 'miscellaneous', 'unknown']
entity_type_dict = {
    "EVE": "event",
    "ORG": "organization",
    "NUMBER": "number",
    "DATE": "date",
    "TIME": "time",
    "PER": "person",
    "CEL": "celestial",
    "Concept": "concept",
    "MEDIA": "media",
    "LOC": "location",
    "MISC": "miscellaneous",
    "UNK": "unknown"
}
system_prompt = {
    "role": "system",
    "content": """You are an entity extractor. You will be given a sentence, you need to extract all the entities from the sentence. 
    The entities must be in one of these types: {entity_types}
    The entities extracted have to match exactly with the text. 
    Reply with the following JSON format: 
        {{
            entities: [
                "text": (string)
                "type": (string, one of the entity types)
                ]
        }}
    """.format(entity_types=list(entity_type_dict.values()))
}
user_prompt = lambda sentence: {
    "role": "user",
    "content": f"""Sentence: {sentence}"""
}
few_shot_prompts = flatten([
    [
        {
            "role": "user",
            "content": example['sentence'], 
        },
        {
            "role": "assistant",
            "content": json.dumps({
                "entities": [
                    {
                        "text": e['name'],
                        "type": entity_type_dict[e['type']]
                    }
                for e in example['entities']
                ]
            }),
        }
    ]
    for example in few_shot_examples
])
prompts = [[system_prompt] + few_shot_prompts + [user_prompt(test_sample['text'])] for test_sample in redfm_test_set]
prompts = prompts
answers = [
    [
        e['surfaceform']
        for e in test_sample['entities']
    ]
    for test_sample in redfm_test_set]
responses = multithread_prompts(openai_client, prompts, model="gpt-4o-mini", temperature=0, format="json")
responses = [json.loads(response)['entities'] for response in responses]
save_json(responses, "decomposed_prompt_entities_v2.json")
# Out:
# 100%|██████████| 446/446 [00:19<00:00, 23.19it/s]

# %%
## relation extraction
# relation extraction
all_relations_str = "\n".join([f"{i}: {r}" for i, r in all_relations.items()])
system_prompt = {
    "role": "system",
    "content": """You are a relation extractor
        You will be given a sentence and a list of entities appearing in the sentence.
        You need to assign a relation between any two entities in the form of a triplet (subject, predicate, object).
        The relation should be one of the following relations:
        {all_relations_str}
        Reply with the following JSON format:
        {{
            triplets: [
                {{
                    subject: (string),
                    predicate: (int, index of the relation in the list),
                    object: (string)
                }}
            ]
        }}
    """.format(all_relations_str=all_relations_str)
}
user_prompt = lambda sentence, entities: {
    "role": "user",
    "content": f"""Sentence: {sentence} \n Entities: {entities}"""
}
few_shot_prompts = flatten([
    [
        {
            "role": "user",
            "content": f"Sentence: {example['sentence']} \n Entities: {example['entities']}", 
        },
        {
            "role": "assistant",
            "content": json.dumps({
                "triplets": example['triplets']
            }),
        }
    ]
    for example in few_shot_examples
])
entities = json.load(open("decomposed_prompt_entities_v2.json"))
prompts = []
for test_sample, entity_responses in zip(redfm_test_set, entities):
    entity_responses = [e['text'] for e in entity_responses]
   # for each combination of entity pairs
    prompts.append([system_prompt] + few_shot_prompts + [user_prompt(test_sample['text'], entity_responses)])
prompts = prompts
answers = [
    [
        {
            "subject": r['subject']['surfaceform'],
            "predicate": int(all_relation_indices[r['predicate']['surfaceform']]),
            "object": r["object"]["surfaceform"]
        }
        for r in test_sample['relations']
    ]
    for test_sample in redfm_test_set]
responses = multithread_prompts(openai_client, prompts, model="gpt-4o-mini", temperature=0, format="json")
responses = [json.loads(response)['triplets'] for response in responses]
save_json(responses, "decomposed_prompt_relations_v2.json")
# Out:
# 100%|██████████| 446/446 [00:11<00:00, 38.51it/s]

# %% [markdown]
# ## Evaluation

# %%
def triplet_correct(predictions, options):
    def _one_triplet_cmp(pred, gold):
        return pred['subject'] == gold['subject'] and pred['object'] == gold['object'] and pred['predicate'] == gold['predicate']
    # if the prediction matches any one of the options, return True
    correct_sum = 0
    for pred in predictions:
        if any([_one_triplet_cmp(pred, gold) for gold in options]):
            # print("prediction: ", pred)
            # print("options:", options)
            correct_sum += 1
    return correct_sum/len(options)

def recall_triplet(predictions, golds):
    return sum([triplet_correct(pred, gold) for pred, gold in zip(predictions, golds)]) / len(golds)


single_prompt_responses = json.load(open("single_prompt_responses.json"))
decomposed_prompt_responses = json.load(open("decomposed_prompt_relations.json"))
decomposed_prompt_responses_v2 = json.load(open("decomposed_prompt_relations_v2.json"))
print(recall_triplet(single_prompt_responses, answers))
print(recall_triplet(decomposed_prompt_responses, answers))
print(recall_triplet(decomposed_prompt_responses_v2, answers))

# print(recall_triplet(responses, answers))
for i, (response, answer) in enumerate(zip(decomposed_prompt_responses_v2, answers)):
    print(f"Sample {i}: {redfm_test_set[i]['text']}")
    print("Response:")
    pprint(response)
    print("Answer:")
    print([{
        "subject": a['subject'],
        "predicate": a['predicate'],
        "object": a['object']
    } for a in answer])
    print("=====================================")
# Out:
# 0.1309882942169938
# 0.14979301341408965
# 0.16245405690472953
# Sample 0: The Porsche Panamera is a mid/full-sized luxury vehicle (E-segment in Europe) manufactured by the German automobile manufacturer Porsche. It is front-engined and has a rear-wheel-drive layout, with all-wheel drive versions also available.
# Response:
# [{'object': 'mid/full-sized luxury vehicle',
#   'predicate': 4,
#   'subject': 'Porsche Panamera'},
#  {'object': 'Porsche', 'predicate': 19, 'subject': 'Porsche Panamera'}]
# Answer:
# [{'subject': 'Porsche Panamera', 'predicate': 19, 'object': 'Porsche'}, {'subject': 'Porsche', 'predicate': 0, 'object': 'German'}]
# =====================================
# Sample 1: Paramount+ (pronounced Paramount Plus; currently named 10 All Access in Australia) is an American subscription video on-demand over-the-top streaming service owned and operated by ViacomCBS Streaming, a division of ViacomCBS. It offers original content, including newly aired CBS broadcast properties, and content from the ViacomCBS library. In the United States, many markets offer a live stream of the local CBS affiliate's main channel.
# Response:
# [{'object': 'subscription video on-demand',
#   'predicate': 14,
#   'subject': 'Paramount+'},
#  {'object': 'over-the-top streaming service',
#   'predicate': 14,
#   'subject': 'Paramount+'},
#  {'object': 'ViacomCBS', 'predicate': 14, 'subject': 'ViacomCBS Streaming'}]
# Answer:
# [{'subject': 'Paramount+', 'predicate': 13, 'object': 'ViacomCBS'}]
# =====================================
# Sample 2: Outside of video games, Paradox has created board games based on several of its titles, and have owned the rights to the tabletop role-playing game series "World of Darkness" since purchasing White Wolf Publishing in 2015. They hold an annual convention, PDXCon, which has been open to the public since 2017.
# Response:
# [{'object': 'board games', 'predicate': 14, 'subject': 'Paradox'},
#  {'object': 'White Wolf Publishing', 'predicate': 11, 'subject': 'Paradox'},
#  {'object': 'tabletop role-playing game series',
#   'predicate': 14,
#   'subject': 'World of Darkness'},
#  {'object': '2017', 'predicate': 31, 'subject': 'PDXCon'}]
# Answer:
# [{'subject': 'World of Darkness', 'predicate': 14, 'object': 'tabletop role-playing game'}]
# =====================================
# Sample 3: Middlesex (; abbreviation: Middx) is a historic county in southeast England. Its area is almost entirely within the wider urbanised area of London and mostly within the ceremonial county of Greater London, with small sections in neighbouring ceremonial counties. It was established in the Anglo-Saxon period from the territory of the Middle Saxons, and existed as an official administrative unit until 1965. The county is bounded to the south by the River Thames, and has the rivers Colne and Lea and a ridge of hills forming its other boundaries. The largely low-lying county, dominated by clay in its north and alluvium on gravel in its south, was the second smallest by area in 1831.
# Response:
# [{'object': 'southeast England', 'predicate': 22, 'subject': 'Middlesex'},
#  {'object': 'London', 'predicate': 21, 'subject': 'Middlesex'},
#  {'object': 'Greater London', 'predicate': 22, 'subject': 'Middlesex'},
#  {'object': '1965', 'predicate': 31, 'subject': 'Middlesex'},
#  {'object': 'River Thames', 'predicate': 23, 'subject': 'Middlesex'}]
# Answer:
# [{'subject': 'Middlesex', 'predicate': 4, 'object': 'historic county'}, {'subject': 'Middlesex', 'predicate': 21, 'object': 'Greater London'}, {'subject': 'Greater London', 'predicate': 4, 'object': 'ceremonial county'}]
# =====================================
# Sample 4: Uther Pendragon (; ), also known as King Uther, is a legendary king of sub-Roman Britain and the father of King Arthur. A few minor references to Uther appear in Old Welsh poems, but his biography was first written down by Geoffrey of Monmouth in his "Historia Regum Britanniae" ("History of the Kings of Britain"), and Geoffrey's account of the character was used in most later versions. He is a fairly ambiguous individual throughout the literature, but is described as a strong king and a defender of his people.
# Response:
# [{'object': 'King Uther', 'predicate': 10, 'subject': 'Uther Pendragon'},
#  {'object': 'King Arthur', 'predicate': 30, 'subject': 'Uther Pendragon'},
#  {'object': 'Historia Regum Britanniae',
#   'predicate': 8,
#   'subject': 'Geoffrey of Monmouth'}]
# Answer:
# [{'subject': 'Uther Pendragon', 'predicate': 6, 'object': 'King Arthur'}, {'subject': 'Geoffrey of Monmouth', 'predicate': 28, 'object': 'Historia Regum Britanniae'}, {'subject': 'Historia Regum Britanniae', 'predicate': 26, 'object': 'Uther Pendragon'}, {'subject': 'Historia Regum Britanniae', 'predicate': 8, 'object': 'Geoffrey of Monmouth'}]
# =====================================
# Sample 5: According to Arthurian legend, Merlin magically disguises Uther to look like his enemy Gorlois, enabling Uther to sleep with Gorlois' wife Lady Igraine. Thus Arthur, "the once and future king", is an illegitimate child (though later legend, as found in Malory, emphasises that the conception occurred after Gorlois's death and that he was legitimated by Uther's subsequent marriage to Igraine). This act of conception occurs the very night that Uther's troops dispatch Gorlois. The theme of illegitimate conception is repeated in Arthur's siring of Mordred by his own half-sister Morgause in the 13th century French prose cycles, which was invented by them; it is Mordred who mortally wounds King Arthur in the Battle of Camlann.
# Response:
# [{'object': 'Lady Igraine', 'predicate': 2, 'subject': 'Uther'},
#  {'object': 'Mordred', 'predicate': 6, 'subject': 'Arthur'},
#  {'object': 'Mordred', 'predicate': 30, 'subject': 'Morgause'},
#  {'object': 'King Arthur', 'predicate': 6, 'subject': 'Mordred'}]
# Answer:
# [{'subject': 'Arthurian legend', 'predicate': 26, 'object': 'Igraine'}, {'subject': 'Gorlois', 'predicate': 2, 'object': 'Igraine'}, {'subject': 'Morgause', 'predicate': 30, 'object': 'King Arthur'}]
# =====================================
# Sample 6: Fußball-Club Ingolstadt 04 e.V., commonly known as FC Ingolstadt 04 or FC Ingolstadt, is a German football club based in Ingolstadt, Bavaria. The club was founded in 2004 out of the merger of the football sides of two other clubs: ESV Ingolstadt and MTV Ingolstadt.
# Response:
# [{'object': 'football club', 'predicate': 4, 'subject': 'FC Ingolstadt 04'},
#  {'object': '2004', 'predicate': 31, 'subject': 'FC Ingolstadt 04'},
#  {'object': 'Ingolstadt', 'predicate': 22, 'subject': 'FC Ingolstadt 04'}]
# Answer:
# [{'subject': 'FC Ingolstadt 04', 'predicate': 25, 'object': 'football'}, {'subject': 'FC Ingolstadt 04', 'predicate': 17, 'object': 'Ingolstadt'}, {'subject': 'club', 'predicate': 25, 'object': 'football'}]
# =====================================
# Sample 7: The firm is registered in Schiphol, the Netherlands as a "naamloze vennootschap" (Dutch public limited company), but the company founders and most of the team members are located in Russia. It primarily serves audiences in Russia and the Commonwealth of Independent States, and also has 18 commercial offices worldwide.
# Response:
# [{'object': 'the Netherlands', 'predicate': 0, 'subject': 'the firm'},
#  {'object': 'Russia', 'predicate': 3, 'subject': 'the firm'},
#  {'object': 'Commonwealth of Independent States',
#   'predicate': 3,
#   'subject': 'the firm'}]
# Answer:
# [{'subject': 'Russia', 'predicate': 24, 'object': 'Commonwealth of Independent States'}]
# =====================================
# Sample 8: Stranger Than Paradise is a 1984 American black-and-white absurdist deadpan comedy film, written, directed and co-edited by Jim Jarmusch, and starring jazz musician John Lurie, former Sonic Youth drummer-turned-actor Richard Edson, and Hungarian-born actress and violinist Eszter Balint. It features a minimalist plot in which the main character, Willie, is visited by Eva, his cousin from Hungary. Eva stays with him for ten days before going to Cleveland. Willie and his friend Eddie go to Cleveland to visit her, and the three then take a trip to Florida. The film is shot entirely in single long takes with no standard coverage.
# Response:
# [{'object': 'Jim Jarmusch',
#   'predicate': 9,
#   'subject': 'Stranger Than Paradise'},
#  {'object': 'John Lurie', 'predicate': 18, 'subject': 'Stranger Than Paradise'},
#  {'object': 'Richard Edson',
#   'predicate': 18,
#   'subject': 'Stranger Than Paradise'},
#  {'object': 'Eszter Balint',
#   'predicate': 18,
#   'subject': 'Stranger Than Paradise'}]
# Answer:
# [{'subject': 'Stranger Than Paradise', 'predicate': 18, 'object': 'John Lurie'}, {'subject': 'Stranger Than Paradise', 'predicate': 18, 'object': 'Richard Edson'}, {'subject': 'Stranger Than Paradise', 'predicate': 18, 'object': 'Eszter Balint'}, {'subject': 'Richard Edson', 'predicate': 22, 'object': 'Sonic Youth'}]
# =====================================
# Sample 9: The former Borgward car manufacturing company, based in Bremen, Germany, was founded by Carl F. W. Borgward (1890–1963). It produced cars of four brands, which were sold to a diversified international customer base: Borgward, Hansa, Goliath and Lloyd. Borgward's Isabella was one of the most popular German premium models in the 1950s, while Lloyd's Alexander / Lloyd 600 model offered affordable mobility to many working-class motorists. The group ceased operations in 1961, following controversial insolvency proceedings.
# Response:
# [{'object': 'Carl F. W. Borgward', 'predicate': 11, 'subject': 'Borgward'},
#  {'object': 'Germany', 'predicate': 4, 'subject': 'Borgward'},
#  {'object': 'Isabella', 'predicate': 14, 'subject': 'Borgward'},
#  {'object': 'Alexander / Lloyd 600', 'predicate': 14, 'subject': 'Lloyd'}]
# Answer:
# [{'subject': 'Borgward', 'predicate': 17, 'object': 'Bremen'}, {'subject': 'Borgward', 'predicate': 11, 'object': 'Carl F. W. Borgward'}, {'subject': 'Bremen', 'predicate': 0, 'object': 'Germany'}, {'subject': 'Carl F. W. Borgward', 'predicate': 3, 'object': 'Germany'}, {'subject': 'Isabella', 'predicate': 19, 'object': 'Borgward'}]
# =====================================
# Sample 10: Anicius Manlius Severinus Boethius, commonly called Boëthius (; also Boetius ; 477 – 524 AD), was a Roman senator, consul, "magister officiorum", and philosopher of the early 6th century. He was born about a year after Odoacer deposed the last Western Roman Emperor and declared himself King of Italy.
# Response:
# [{'object': 'Roman senator',
#   'predicate': 10,
#   'subject': 'Anicius Manlius Severinus Boethius'},
#  {'object': 'consul',
#   'predicate': 10,
#   'subject': 'Anicius Manlius Severinus Boethius'},
#  {'object': 'magister officiorum',
#   'predicate': 10,
#   'subject': 'Anicius Manlius Severinus Boethius'},
#  {'object': 'philosopher',
#   'predicate': 10,
#   'subject': 'Anicius Manlius Severinus Boethius'}]
# Answer:
# [{'subject': 'Boethius', 'predicate': 10, 'object': 'philosopher'}]
# =====================================
# Sample 11: "The Tell-Tale Heart" is a short story by American writer Edgar Allan Poe, first published in 1843. It is related by an unnamed narrator who endeavors to convince the reader of the narrator's sanity while simultaneously describing a murder the narrator committed. The victim was an old man with a filmy pale blue "vulture-eye", as the narrator calls it. The narrator emphasizes the careful calculation of the murder, attempting the perfect crime, complete with dismembering the body in the bathtub and hiding it under the floorboards. Ultimately, the narrator's actions result in hearing a thumping sound, which the narrator interprets as the dead man's beating heart.
# Response:
# [{'object': 'Edgar Allan Poe',
#   'predicate': 8,
#   'subject': 'The Tell-Tale Heart'}]
# Answer:
# [{'subject': 'The Tell-Tale Heart', 'predicate': 8, 'object': 'Edgar Allan Poe'}, {'subject': 'Edgar Allan Poe', 'predicate': 28, 'object': 'The Tell-Tale Heart'}]
# =====================================
# Sample 12: Island Records is a British-Jamaican record label owned by Universal Music Group. It was founded in 1959 by Chris Blackwell, Graeme Goodall, and Leslie Kong in Jamaica, and was eventually sold to PolyGram in 1989. Island and A&M Records, another label recently acquired by PolyGram, were both at the time the largest independent record labels in history, with Island having exerted a major influence on the progressive music scene in the United Kingdom in the early 1970s.
# Response:
# [{'object': 'largest independent record labels',
#   'predicate': 14,
#   'subject': 'Island Records'},
#  {'object': 'Chris Blackwell', 'predicate': 11, 'subject': 'Island Records'},
#  {'object': 'Graeme Goodall', 'predicate': 11, 'subject': 'Island Records'},
#  {'object': 'Leslie Kong', 'predicate': 11, 'subject': 'Island Records'},
#  {'object': 'Universal Music Group',
#   'predicate': 3,
#   'subject': 'Island Records'}]
# Answer:
# [{'subject': 'Island Records', 'predicate': 4, 'object': 'record label'}, {'subject': 'Island Records', 'predicate': 11, 'object': 'Chris Blackwell'}, {'subject': 'Island Records', 'predicate': 11, 'object': 'Graeme Goodall'}, {'subject': 'Island Records', 'predicate': 13, 'object': 'Universal Music Group'}]
# =====================================
# Sample 13: "The Murders in the Rue Morgue" is a short story by Edgar Allan Poe published in "Graham's Magazine" in 1841. It has been described as the first modern detective story; Poe referred to it as one of his "tales of ".
# Response:
# [{'object': 'Edgar Allan Poe',
#   'predicate': 8,
#   'subject': 'The Murders in the Rue Morgue'},
#  {'object': 'first modern detective story',
#   'predicate': 28,
#   'subject': 'The Murders in the Rue Morgue'}]
# Answer:
# [{'subject': 'The Murders in the Rue Morgue', 'predicate': 8, 'object': 'Edgar Allan Poe'}, {'subject': 'Edgar Allan Poe', 'predicate': 28, 'object': 'The Murders in the Rue Morgue'}]
# =====================================
# Sample 14: The White Stripes were an American rock duo from Detroit, Michigan formed in 1997. The group consisted of Jack White (songwriter, vocals, guitar, piano, and mandolin) and his one-time wife Meg White (drums and vocals). After releasing several singles and three albums within the Detroit music scene, the White Stripes rose to prominence in 2002 as part of the garage rock revival scene. Their successful and critically acclaimed albums "White Blood Cells" and "Elephant" drew attention from a large variety of media outlets in the United States and the United Kingdom. The single "Seven Nation Army", which used a guitar and an octave pedal to create the iconic opening riff, became one of their most recognizable songs. The band recorded two more albums, "Get Behind Me Satan" in 2005 and "Icky Thump" in 2007, and dissolved in 2011 after a lengthy hiatus from performing and recording.
# Response:
# [{'object': 'American rock duo',
#   'predicate': 4,
#   'subject': 'The White Stripes'},
#  {'object': 'Jack White', 'predicate': 18, 'subject': 'The White Stripes'},
#  {'object': 'Meg White', 'predicate': 18, 'subject': 'The White Stripes'},
#  {'object': 'White Blood Cells',
#   'predicate': 28,
#   'subject': 'The White Stripes'},
#  {'object': 'Elephant', 'predicate': 28, 'subject': 'The White Stripes'},
#  {'object': 'Get Behind Me Satan',
#   'predicate': 28,
#   'subject': 'The White Stripes'},
#  {'object': 'Icky Thump', 'predicate': 28, 'subject': 'The White Stripes'}]
# Answer:
# [{'subject': 'The White Stripes', 'predicate': 31, 'object': '1997'}, {'subject': 'The White Stripes', 'predicate': 14, 'object': 'garage rock revival'}, {'subject': 'Jack White', 'predicate': 22, 'object': 'The White Stripes'}, {'subject': 'Jack White', 'predicate': 2, 'object': 'Meg White'}, {'subject': 'Meg White', 'predicate': 22, 'object': 'The White Stripes'}, {'subject': 'Elephant', 'predicate': 16, 'object': 'White Blood Cells'}, {'subject': 'Icky Thump', 'predicate': 16, 'object': 'Get Behind Me Satan'}]
# =====================================
# Sample 15: In early 2000, both Roberson and Luckett were replaced with Williams and Farrah Franklin; however, Franklin quit after five months, leaving the group as a trio. Their third album, "Survivor" (2001), whose themes the public interpreted as a channel to the group's experience, produced the worldwide hits "Independent Women", "Survivor" and "Bootylicious". In 2001, they announced a hiatus to pursue solo careers. The trio reunited two years later for the release of their fifth and final studio album, "Destiny Fulfilled" (2004), which spawned the international hits "Lose My Breath" and "Soldier". Since the group's official disbandment in 2006, Knowles, Rowland, and Williams have reunited a couple of times, including at the 2013 Super Bowl halftime show and 2018 Coachella festival.
# Response:
# [{'object': 'Luckett', 'predicate': 30, 'subject': 'Roberson'},
#  {'object': 'Farrah Franklin', 'predicate': 2, 'subject': 'Williams'},
#  {'object': 'Independent Women', 'predicate': 28, 'subject': 'Survivor'},
#  {'object': 'Bootylicious', 'predicate': 28, 'subject': 'Survivor'},
#  {'object': 'Lose My Breath', 'predicate': 28, 'subject': 'Destiny Fulfilled'},
#  {'object': 'Soldier', 'predicate': 28, 'subject': 'Destiny Fulfilled'},
#  {'object': 'Rowland', 'predicate': 30, 'subject': 'Knowles'},
#  {'object': 'Williams', 'predicate': 30, 'subject': 'Knowles'}]
# Answer:
# [{'subject': 'Independent Women', 'predicate': 22, 'object': 'Survivor'}, {'subject': 'Survivor', 'predicate': 16, 'object': 'Independent Women'}, {'subject': 'Bootylicious', 'predicate': 22, 'object': 'Survivor'}, {'subject': 'Bootylicious', 'predicate': 16, 'object': 'Survivor'}, {'subject': 'Lose My Breath', 'predicate': 22, 'object': 'Destiny Fulfilled'}, {'subject': 'Soldier', 'predicate': 22, 'object': 'Destiny Fulfilled'}, {'subject': 'Soldier', 'predicate': 16, 'object': 'Lose My Breath'}]
# =====================================
# Sample 16: In Quentin Tarantino's Once Upon a Time in Hollywood, Al Pacino plays a character with a similar name (Marvin Schwarz) who is a producer and talent scout. The similarity is apparently coincidental, and the character is not modelled on the real-life Schwartz.
# Response:
# [{'object': 'Marvin Schwarz', 'predicate': 18, 'subject': 'Al Pacino'},
#  {'object': 'Quentin Tarantino',
#   'predicate': 8,
#   'subject': 'Once Upon a Time in Hollywood'}]
# Answer:
# [{'subject': 'Once Upon a Time in Hollywood', 'predicate': 9, 'object': 'Quentin Tarantino'}]
# =====================================
# Sample 17: The Nikon D200 is a 10.2-megapixel digital single-lens reflex camera that falls between entry-level/midrange DSLR cameras such as the Nikon D40, Nikon D40x, and D80 and high-end models such as the Nikon D2Hs and D2Xs. It was released by the Nikon Corporation in November 2005. The D200 was succeeded by the D300 in August 2007.
# Response:
# [{'object': 'digital single-lens reflex camera',
#   'predicate': 4,
#   'subject': 'Nikon D200'},
#  {'object': 'November 2005', 'predicate': 31, 'subject': 'Nikon D200'},
#  {'object': 'Nikon D200', 'predicate': 29, 'subject': 'D300'}]
# Answer:
# [{'subject': 'Nikon D200', 'predicate': 4, 'object': 'digital single-lens reflex camera'}, {'subject': 'Nikon D200', 'predicate': 19, 'object': 'Nikon Corporation'}, {'subject': 'D80', 'predicate': 4, 'object': 'digital single-lens reflex camera'}, {'subject': 'Nikon D2Hs', 'predicate': 4, 'object': 'digital single-lens reflex camera'}, {'subject': 'D2Xs', 'predicate': 4, 'object': 'digital single-lens reflex camera'}, {'subject': 'D300', 'predicate': 16, 'object': 'Nikon D200'}]
# =====================================
# Sample 18: Ricola Ltd./Ricola AG is a Swiss manufacturer of cough drops and breath mints. The head office of Ricola is located in Laufen, Basel-Country.
# Response:
# [{'object': 'cough drops', 'predicate': 19, 'subject': 'Ricola Ltd./Ricola AG'},
#  {'object': 'breath mints',
#   'predicate': 19,
#   'subject': 'Ricola Ltd./Ricola AG'},
#  {'object': 'Laufen', 'predicate': 17, 'subject': 'Ricola Ltd./Ricola AG'},
#  {'object': 'Basel-Country', 'predicate': 22, 'subject': 'Laufen'}]
# Answer:
# [{'subject': 'cough drop', 'predicate': 19, 'object': 'Ricola'}, {'subject': 'Ricola', 'predicate': 17, 'object': 'Laufen'}, {'subject': 'Laufen', 'predicate': 21, 'object': 'Basel-Country'}]
# =====================================
# Sample 19: Dredd is a 2012 science fiction action film directed by Pete Travis and written and produced by Alex Garland. It is based on the "2000 AD" comic strip "Judge Dredd" and its eponymous character created by John Wagner and Carlos Ezquerra. Karl Urban stars as Judge Dredd, a law enforcer given the power of judge, jury and executioner in a vast, dystopic metropolis called Mega-City One that lies in a post-apocalyptic wasteland. Dredd and his apprentice partner, Judge Anderson (Olivia Thirlby), are forced to bring order to a 200-storey high-rise block of flats and deal with its resident drug lord, Ma-Ma (Lena Headey).
# Response:
# [{'object': 'science fiction action film', 'predicate': 4, 'subject': 'Dredd'},
#  {'object': 'Pete Travis', 'predicate': 9, 'subject': 'Dredd'},
#  {'object': 'Alex Garland', 'predicate': 8, 'subject': 'Dredd'},
#  {'object': 'John Wagner', 'predicate': 8, 'subject': 'Judge Dredd'},
#  {'object': 'Carlos Ezquerra', 'predicate': 8, 'subject': 'Judge Dredd'},
#  {'object': 'Karl Urban', 'predicate': 18, 'subject': 'Dredd'},
#  {'object': 'Judge Anderson', 'predicate': 18, 'subject': 'Dredd'},
#  {'object': 'Olivia Thirlby', 'predicate': 18, 'subject': 'Judge Anderson'}]
# Answer:
# [{'subject': 'Dredd', 'predicate': 14, 'object': 'science fiction'}, {'subject': 'Dredd', 'predicate': 14, 'object': 'action film'}, {'subject': 'Dredd', 'predicate': 9, 'object': 'Pete Travis'}, {'subject': '2000 AD', 'predicate': 22, 'object': 'Judge Dredd'}, {'subject': 'Dredd', 'predicate': 18, 'object': 'Karl Urban'}, {'subject': 'Dredd', 'predicate': 26, 'object': 'Judge Anderson'}, {'subject': 'Dredd', 'predicate': 18, 'object': 'Olivia Thirlby'}, {'subject': 'Dredd', 'predicate': 18, 'object': 'Lena Headey'}]
# =====================================
# Sample 20: "The Emperor's New Clothes" ( ) is a literary folktale written by Danish author Hans Christian Andersen, about a vain emperor who gets exposed before his subjects. The tale has been translated into over 100 languages.
# Response:
# [{'object': 'Hans Christian Andersen',
#   'predicate': 8,
#   'subject': "The Emperor's New Clothes"}]
# Answer:
# [{'subject': "The Emperor's New Clothes", 'predicate': 8, 'object': 'Hans Christian Andersen'}, {'subject': 'Hans Christian Andersen', 'predicate': 28, 'object': "The Emperor's New Clothes"}]
# =====================================
# Sample 21: Sportsklubben Brann (commonly known as Brann, and less often as SK Brann) is a Norwegian professional football club, founded 26 September 1908, from Bergen. Brann has been in the Eliteserien, Norway's Premier Division of Football, since 1987, bar one season spent in the 1. divisjon in 2015. They play their home matches at Brann Stadion where they had a record-breaking 17,310 in average attendance in the 2007 season. In October 2007, Brann won the Norwegian league title for the first time since 1963.
# Response:
# [{'object': '26 September 1908',
#   'predicate': 31,
#   'subject': 'Sportsklubben Brann'},
#  {'object': 'Bergen', 'predicate': 22, 'subject': 'Brann'},
#  {'object': 'Eliteserien', 'predicate': 24, 'subject': 'Brann'},
#  {'object': 'Norwegian league title', 'predicate': 28, 'subject': 'Brann'}]
# Answer:
# [{'subject': 'SK Brann', 'predicate': 25, 'object': 'football'}, {'subject': 'SK Brann', 'predicate': 17, 'object': 'Bergen'}, {'subject': 'SK Brann', 'predicate': 12, 'object': 'Eliteserien'}]
# =====================================
# Sample 22: Clube Atlético Mineiro (), commonly known as Atlético Mineiro or Atlético, and colloquially as Galo (, "Rooster"), is a professional football club based in the city of Belo Horizonte, capital city of the Brazilian state of Minas Gerais. The team competes in the Campeonato Brasileiro Série A, the first level of Brazilian football, as well as in the Campeonato Mineiro, the top tier state league of Minas Gerais.
# Response:
# [{'object': 'Atlético Mineiro',
#   'predicate': 4,
#   'subject': 'Clube Atlético Mineiro'},
#  {'object': 'Atlético', 'predicate': 4, 'subject': 'Clube Atlético Mineiro'},
#  {'object': 'Belo Horizonte',
#   'predicate': 21,
#   'subject': 'Clube Atlético Mineiro'},
#  {'object': 'Minas Gerais',
#   'predicate': 22,
#   'subject': 'Clube Atlético Mineiro'},
#  {'object': 'Campeonato Brasileiro Série A',
#   'predicate': 24,
#   'subject': 'Clube Atlético Mineiro'},
#  {'object': 'Campeonato Mineiro',
#   'predicate': 24,
#   'subject': 'Clube Atlético Mineiro'}]
# Answer:
# [{'subject': 'Clube Atlético Mineiro', 'predicate': 17, 'object': 'Belo Horizonte'}, {'subject': 'Clube Atlético Mineiro', 'predicate': 12, 'object': 'Campeonato Brasileiro Série A'}, {'subject': 'Belo Horizonte', 'predicate': 4, 'object': 'capital city'}, {'subject': 'Belo Horizonte', 'predicate': 21, 'object': 'Minas Gerais'}, {'subject': 'Minas Gerais', 'predicate': 5, 'object': 'Belo Horizonte'}, {'subject': 'Minas Gerais', 'predicate': 4, 'object': 'Brazilian state'}]
# =====================================
# Sample 23: The 2000s have seen the club win only four state titles. Bahia was demoted to the "Série B" in 2003 and demoted, for the first time ever, to the Série C in 2005, spending two seasons at the bottom of the Brazilian league system. In 2007, they were promoted back to the second level, and in 2010 the club found itself back in the "Série A", after eight seasons. Bahia had played its home games with 66,080 people capacity Estádio Fonte Nova since 1951 but after a section of the stadium collapsed in 2007, the "Tricolor" played at the Estádio de Pituaçu. With the reopening of the Fonte Nova stadium in 2013 as the Arena Fonte Nova, a modern arena built for the 2014 FIFA World Cup, Bahia resumed playing its matches there. The club's home uniform consists of white shirts with blue shorts and red socks. It has a long-standing rivalry with the Vitória and matches between the two sides are known as Ba–Vi.
# Response:
# [{'object': '2003', 'predicate': 31, 'subject': 'Bahia'},
#  {'object': '2005', 'predicate': 31, 'subject': 'Bahia'},
#  {'object': '2007', 'predicate': 31, 'subject': 'Bahia'},
#  {'object': '2010', 'predicate': 31, 'subject': 'Bahia'},
#  {'object': '2013', 'predicate': 31, 'subject': 'Bahia'},
#  {'object': 'Estádio Fonte Nova', 'predicate': 22, 'subject': 'Bahia'},
#  {'object': 'Estádio de Pituaçu', 'predicate': 22, 'subject': 'Bahia'},
#  {'object': 'Arena Fonte Nova', 'predicate': 22, 'subject': 'Bahia'},
#  {'object': 'Vitória', 'predicate': 24, 'subject': 'Bahia'}]
# Answer:
# [{'subject': '2014 FIFA World Cup', 'predicate': 21, 'object': 'Arena Fonte Nova'}]
# =====================================
# Sample 24: These features made the T-64 expensive to build, significantly more so than previous generations of Soviet tanks. This was especially true of the power pack, which was time-consuming to build and cost twice as much as more conventional designs. Several proposals were made to improve the T-64 with new engines, but chief designer Alexander Morozov's political power in Moscow kept the design in production in spite of any concerns about price. This led to the T-72 being designed as an emergency design, only to be produced in the case of a war, but its 40% lower price led to it entering production in spite of Morozov's objections.
# Response:
# [{'object': 'Soviet tanks', 'predicate': 14, 'subject': 'T-64'},
#  {'object': 'power pack', 'predicate': 19, 'subject': 'T-64'},
#  {'object': 'chief designer', 'predicate': 10, 'subject': 'Alexander Morozov'},
#  {'object': 'T-64', 'predicate': 31, 'subject': 'T-72'}]
# Answer:
# [{'subject': 'T-72', 'predicate': 16, 'object': 'T-64'}]
# =====================================
# Sample 25: De Nederlandsche Bank NV (DNB) is the central bank of the Netherlands. Founded by King William I in 1814, it is part of the European System of Central Banks (ESCB). De Nederlandsche Bank is a public limited company (Dutch: "naamloze vennootschap", abbreviated NV) whose every day policy is overseen by the Governing Board. Being an NV, DNB has a Supervisory Board (Dutch: "Raad van Commissarissen").
# Response:
# [{'object': 'central bank',
#   'predicate': 4,
#   'subject': 'De Nederlandsche Bank NV'},
#  {'object': 'King William I',
#   'predicate': 11,
#   'subject': 'De Nederlandsche Bank NV'},
#  {'object': '1814', 'predicate': 31, 'subject': 'De Nederlandsche Bank NV'},
#  {'object': 'European System of Central Banks',
#   'predicate': 24,
#   'subject': 'De Nederlandsche Bank NV'},
#  {'object': 'public limited company',
#   'predicate': 14,
#   'subject': 'De Nederlandsche Bank NV'}]
# Answer:
# [{'subject': 'De Nederlandsche Bank', 'predicate': 4, 'object': 'central bank'}, {'subject': 'De Nederlandsche Bank', 'predicate': 0, 'object': 'Netherlands'}, {'subject': 'De Nederlandsche Bank', 'predicate': 11, 'object': 'King William I'}, {'subject': 'De Nederlandsche Bank', 'predicate': 22, 'object': 'European System of Central Banks'}]
# =====================================
# Sample 26: were a music group formed in 1958, featuring brothers Barry, Robin, and Maurice Gibb. The trio were especially successful as a popular music act in the late 1960s and early 1970s, and later as prominent performers of the disco music era in the mid- to late 1970s. The group sang recognisable three-part tight harmonies; Robin's clear vibrato lead vocals were a hallmark of their earlier hits, while Barry's R&B falsetto became their signature sound during the mid- to late 1970s and 1980s. The Bee Gees wrote all of their own hits, as well as writing and producing several major hits for other artists. The Bee Gees have occasionally been referred to as the Kings of Disco.
# Response:
# [{'object': 'music group', 'predicate': 4, 'subject': 'Bee Gees'},
#  {'object': '1958', 'predicate': 31, 'subject': 'Bee Gees'},
#  {'object': 'Barry Gibb', 'predicate': 18, 'subject': 'Bee Gees'},
#  {'object': 'Robin Gibb', 'predicate': 18, 'subject': 'Bee Gees'},
#  {'object': 'Maurice Gibb', 'predicate': 18, 'subject': 'Bee Gees'}]
# Answer:
# [{'subject': 'Barry', 'predicate': 30, 'object': 'Robin'}, {'subject': 'Barry', 'predicate': 30, 'object': 'Maurice Gibb'}, {'subject': 'Robin', 'predicate': 30, 'object': 'Maurice Gibb'}]
# =====================================
# Sample 27: The Seventh Seal () is a 1957 Swedish historical fantasy film written and directed by Ingmar Bergman. Set in Sweden during the Black Death, it tells of the journey of a medieval knight (Max von Sydow) and a game of chess he plays with the personification of Death (Bengt Ekerot), who has come to take his life. Bergman developed the film from his own play "Wood Painting". The title refers to a passage from the Book of Revelation, used both at the very start of the film, and again towards the end, beginning with the words "And when the Lamb had opened the seventh seal, there was silence in heaven about the space of half an hour". Here, the motif of silence refers to the "silence of God", which is a major theme of the film.
# Response:
# [{'object': 'historical fantasy film',
#   'predicate': 4,
#   'subject': 'The Seventh Seal'},
#  {'object': 'Ingmar Bergman', 'predicate': 9, 'subject': 'The Seventh Seal'},
#  {'object': 'Sweden', 'predicate': 21, 'subject': 'The Seventh Seal'},
#  {'object': 'Wood Painting', 'predicate': 28, 'subject': 'The Seventh Seal'},
#  {'object': 'Death', 'predicate': 26, 'subject': 'The Seventh Seal'}]
# Answer:
# [{'subject': 'The Seventh Seal', 'predicate': 9, 'object': 'Ingmar Bergman'}, {'subject': 'The Seventh Seal', 'predicate': 18, 'object': 'Max von Sydow'}, {'subject': 'The Seventh Seal', 'predicate': 18, 'object': 'Bengt Ekerot'}, {'subject': 'Ingmar Bergman', 'predicate': 28, 'object': 'The Seventh Seal'}, {'subject': 'seventh seal', 'predicate': 22, 'object': 'Book of Revelation'}]
# =====================================
# Sample 28: Melanesia (, ) is a subregion of Oceania in the southwestern Pacific Ocean. It extends from the island of New Guinea in the west to Tonga in the east, and includes the Arafura Sea.
# Response:
# [{'object': 'Oceania', 'predicate': 22, 'subject': 'Melanesia'},
#  {'object': 'Pacific Ocean', 'predicate': 7, 'subject': 'Melanesia'},
#  {'object': 'New Guinea', 'predicate': 21, 'subject': 'Melanesia'},
#  {'object': 'Tonga', 'predicate': 21, 'subject': 'Melanesia'},
#  {'object': 'Arafura Sea', 'predicate': 21, 'subject': 'Melanesia'}]
# Answer:
# [{'subject': 'Melanesia', 'predicate': 20, 'object': 'Pacific Ocean'}, {'subject': 'New Guinea', 'predicate': 20, 'object': 'Arafura Sea'}]
# =====================================
# Sample 29: A manga series adaptation by Datto Nishiwaki was serialized in Kadokawa Shoten's "Shōnen Ace" magazine between the February 2006 and December 2012 issues. In 2007, the manga was licensed for an English-language release in North America by Tokyopop. A 24-episode anime series created by Studio Deen aired in Japan between January and June 2006. Sentai Filmworks has licensed the television series and re-released the series on DVD and for the first time on Blu-ray Disc. A film adaptation by Studio Deen was released in Japanese theaters on January 23, 2010. A second anime television series, "Fate/stay night: Unlimited Blade Works", was produced by Ufotable and aired between October 2014 and June 2015, following the game's second route as opposed to the first. A second manga adaptation began in 2015 focusing solely on the third route. A film trilogy adapted the Heaven's Feel route of the visual novel, with the first film, titled "presage flower", released in 2017, the second film, titled "lost butterfly", released in 2019, and the final film, titled "spring song" released in late 2020 after postponement due to the COVID-19 pandemic.
# Response:
# [{'object': 'Datto Nishiwaki', 'predicate': 11, 'subject': 'manga series'},
#  {'object': 'Kadokawa Shoten', 'predicate': 24, 'subject': 'manga series'},
#  {'object': 'Shōnen Ace', 'predicate': 24, 'subject': 'manga series'},
#  {'object': 'Studio Deen', 'predicate': 9, 'subject': 'anime series'},
#  {'object': 'Ufotable',
#   'predicate': 9,
#   'subject': 'Fate/stay night: Unlimited Blade Works'},
#  {'object': 'Studio Deen', 'predicate': 11, 'subject': 'film adaptation'}]
# Answer:
# [{'subject': 'DVD', 'predicate': 19, 'object': 'Sentai Filmworks'}, {'subject': 'Blu-ray Disc', 'predicate': 16, 'object': 'DVD'}]
# =====================================
# Sample 30: Adobe Shockwave (formerly Macromedia Shockwave) is a discontinued multimedia platform for building interactive multimedia applications and video games. Developers originate content using Adobe Director and publish it on the Internet. Such content could be viewed in a web browser on any computer with the Shockwave Player plug-in installed. MacroMind originated the technology; Macromedia acquired MacroMind and developed it further, releasing Shockwave Player in 1995. Adobe then acquired Shockwave with Macromedia in 2005. Shockwave supports raster graphics, basic vector graphics, 3D graphics, audio, and an embedded scripting language called Lingo.
# Response:
# [{'object': 'multimedia platform',
#   'predicate': 4,
#   'subject': 'Adobe Shockwave'},
#  {'object': 'Lingo', 'predicate': 14, 'subject': 'Shockwave Player'},
#  {'object': 'Macromedia', 'predicate': 11, 'subject': 'MacroMind'}]
# Answer:
# [{'subject': 'Adobe Shockwave', 'predicate': 4, 'object': 'platform'}, {'subject': 'Adobe Shockwave', 'predicate': 19, 'object': 'MacroMind'}, {'subject': 'Adobe Shockwave', 'predicate': 19, 'object': 'Macromedia'}]
# =====================================
# Sample 31: During the 1990s, Shockwave was a common format for CD-ROM projectors, kiosk presentations, and interactive video games, and dominated in interactive multimedia. Various graphic adventure games were developed with Shockwave then, including "The Journeyman Project", "Total Distortion", "Eastern Mind: The Lost Souls of Tong Nou", "Mia's Language Adventure", "Mia's Science Adventure", and the "Didi & Ditto" series. Video game developers developed hundreds of free online video games using Shockwave, publishing them on websites such as Miniclip and Shockwave.com.
# Response:
# [{'object': 'interactive multimedia', 'predicate': 14, 'subject': 'Shockwave'},
#  {'object': 'graphic adventure games',
#   'predicate': 4,
#   'subject': 'The Journeyman Project'},
#  {'object': 'graphic adventure games',
#   'predicate': 4,
#   'subject': 'Total Distortion'},
#  {'object': 'graphic adventure games',
#   'predicate': 4,
#   'subject': 'Eastern Mind: The Lost Souls of Tong Nou'},
#  {'object': 'graphic adventure games',
#   'predicate': 4,
#   'subject': "Mia's Language Adventure"},
#  {'object': 'graphic adventure games',
#   'predicate': 4,
#   'subject': "Mia's Science Adventure"},
#  {'object': 'graphic adventure games',
#   'predicate': 4,
#   'subject': 'Didi & Ditto'}]
# Answer:
# [{'subject': 'The Journeyman Project', 'predicate': 14, 'object': 'graphic adventure game'}, {'subject': 'Total Distortion', 'predicate': 14, 'object': 'graphic adventure game'}]
# =====================================
# Sample 32: "The Adventure of the Speckled Band" is the eighth Sherlock Holmes short story, and the tenth Holmes story overall (following the novels "A Study in Scarlet" and "The Sign of the Four)", by British author Sir Arthur Conan Doyle. It was originally published in "Strand Magazine" in February 1892, with illustrations by Sidney Paget, and later as the eighth story in the collection "The Adventures of Sherlock Holmes". The story tells of Helen Stoner, a soon-to-be married young woman who suspects her stepfather may be trying to kill her in order to retain control of her inheritance. Convinced of her stepfather's intentions, she turns to Holmes for help.
# Response:
# [{'object': 'Sir Arthur Conan Doyle',
#   'predicate': 8,
#   'subject': 'The Adventure of the Speckled Band'},
#  {'object': 'Sherlock Holmes',
#   'predicate': 4,
#   'subject': 'The Adventure of the Speckled Band'},
#  {'object': 'The Adventures of Sherlock Holmes',
#   'predicate': 28,
#   'subject': 'The Adventure of the Speckled Band'},
#  {'object': 'A Study in Scarlet',
#   'predicate': 28,
#   'subject': 'The Adventure of the Speckled Band'},
#  {'object': 'The Sign of the Four',
#   'predicate': 28,
#   'subject': 'The Adventure of the Speckled Band'}]
# Answer:
# [{'subject': 'The Adventure of the Speckled Band', 'predicate': 8, 'object': 'Sir Arthur Conan Doyle'}, {'subject': 'A Study in Scarlet', 'predicate': 8, 'object': 'Sir Arthur Conan Doyle'}, {'subject': 'The Sign of the Four', 'predicate': 16, 'object': 'A Study in Scarlet'}, {'subject': 'The Sign of the Four', 'predicate': 8, 'object': 'Sir Arthur Conan Doyle'}]
# =====================================
# Sample 33: Tender Is the Night is the fourth and final novel completed by American writer F. Scott Fitzgerald. It was first published in "Scribner's Magazine" between January and April 1934 in four issues. The title is taken from the poem "Ode to a Nightingale" by John Keats.
# Response:
# [{'object': 'F. Scott Fitzgerald',
#   'predicate': 8,
#   'subject': 'Tender Is the Night'},
#  {'object': 'Ode to a Nightingale',
#   'predicate': 28,
#   'subject': 'Tender Is the Night'},
#  {'object': 'John Keats', 'predicate': 8, 'subject': 'Ode to a Nightingale'}]
# Answer:
# [{'subject': 'Tender Is the Night', 'predicate': 8, 'object': 'F. Scott Fitzgerald'}, {'subject': 'Ode to a Nightingale', 'predicate': 8, 'object': 'John Keats'}]
# =====================================
# Sample 34: Lenovo Group Limited, often shortened to Lenovo ( ), is a Chinese multinational technology company. Incorporated in Hong Kong, it has global headquarters in Beijing, China, operational headquarters in Morrisville, North Carolina, US, and an operational center in Singapore. The company designs, develops, manufactures, and sells personal computers, tablet computers, smartphones, workstations, servers, supercomputers, electronic storage devices, IT management software, and smart televisions, and is the world's largest personal computer vendor by unit sales as of January 2021. It also markets the ThinkPad and ThinkBook business lines of laptop computers; IdeaPad, Yoga, and Legion consumer lines of laptop computers; and the IdeaCentre and ThinkCentre lines of desktop computers.
# Response:
# [{'object': 'multinational technology company',
#   'predicate': 4,
#   'subject': 'Lenovo Group Limited'},
#  {'object': 'Beijing', 'predicate': 17, 'subject': 'Lenovo Group Limited'},
#  {'object': 'Morrisville', 'predicate': 17, 'subject': 'Lenovo Group Limited'},
#  {'object': 'Singapore', 'predicate': 17, 'subject': 'Lenovo Group Limited'},
#  {'object': 'China', 'predicate': 3, 'subject': 'Lenovo Group Limited'}]
# Answer:
# [{'subject': 'Lenovo', 'predicate': 17, 'object': 'Beijing'}, {'subject': 'Morrisville', 'predicate': 21, 'object': 'North Carolina'}, {'subject': 'tablet computer', 'predicate': 19, 'object': 'Lenovo'}]
# =====================================
# Sample 35: Apple Pencil is a line of wireless stylus pen accessories designed and developed by Apple Inc. for use with supported iPad tablets.
# Response:
# [{'object': 'Apple Inc.', 'predicate': 19, 'subject': 'Apple Pencil'}]
# Answer:
# [{'subject': 'Apple Pencil', 'predicate': 4, 'object': 'stylus'}, {'subject': 'Apple Pencil', 'predicate': 19, 'object': 'Apple Inc.'}, {'subject': 'iPad', 'predicate': 19, 'object': 'Apple Inc.'}, {'subject': 'iPad', 'predicate': 4, 'object': 'tablets'}]
# =====================================
# Sample 36: Acura is the luxury vehicle division of Japanese automaker Honda. The brand was launched in the United States and Canada on 27 March 1986, marketing luxury, performance, and high-performance automobiles. It was introduced to Hong Kong in 1991 (lasting until 2009), Mexico in 2004, China in 2006, Russia in 2014 (no longer available in Russia) and Kuwait in 2015, and was also sold in Ukraine (until 2018). Honda's plan to introduce Acura to the Japanese domestic market (JDM) in 2008 was delayed, due to economic reasons, and later withheld as a result of the financial crisis of 2007–2008.
# Response:
# [{'object': 'Honda', 'predicate': 4, 'subject': 'Acura'},
#  {'object': 'United States', 'predicate': 21, 'subject': 'Acura'},
#  {'object': 'Canada', 'predicate': 21, 'subject': 'Acura'},
#  {'object': 'Hong Kong', 'predicate': 21, 'subject': 'Acura'},
#  {'object': 'Mexico', 'predicate': 21, 'subject': 'Acura'},
#  {'object': 'China', 'predicate': 21, 'subject': 'Acura'},
#  {'object': 'Russia', 'predicate': 21, 'subject': 'Acura'},
#  {'object': 'Kuwait', 'predicate': 21, 'subject': 'Acura'},
#  {'object': 'Ukraine', 'predicate': 21, 'subject': 'Acura'}]
# Answer:
# [{'subject': 'Acura', 'predicate': 11, 'object': 'Honda'}, {'subject': 'luxury vehicle', 'predicate': 19, 'object': 'Acura'}]
# =====================================
# Sample 37: The Carlton Football Club, nicknamed the Blues, is a professional Australian rules football club that competes in the Australian Football League (AFL), the sport's elite competition.
# Response:
# [{'object': 'Australian rules football',
#   'predicate': 10,
#   'subject': 'Carlton Football Club'},
#  {'object': 'Australian Football League',
#   'predicate': 24,
#   'subject': 'Carlton Football Club'}]
# Answer:
# [{'subject': 'Carlton Football Club', 'predicate': 25, 'object': 'Australian rules football'}, {'subject': 'Carlton Football Club', 'predicate': 12, 'object': 'Australian Football League'}, {'subject': 'Australian Football League', 'predicate': 25, 'object': 'Australian rules football'}]
# =====================================
# Sample 38: Neferneferuaten Nefertiti () (c. 1370 – c. 1330 BC) was a queen of the 18th Dynasty of Ancient Egypt, the Great Royal Wife of Pharaoh Akhenaten. Nefertiti and her husband were known for a religious revolution, in which they worshipped one god only, Aten, or the sun disc. With her husband, she reigned at what was arguably the wealthiest period of Ancient Egyptian history. Some scholars believe that Nefertiti ruled briefly as Neferneferuaten after her husband's death and before the ascension of Tutankhamun, although this identification is a matter of ongoing debate. If Nefertiti did rule as Pharaoh, her reign was marked by the fall of Amarna and relocation of the capital back to the traditional city of Thebes.
# Response:
# [{'object': '18th Dynasty',
#   'predicate': 4,
#   'subject': 'Neferneferuaten Nefertiti'},
#  {'object': 'Pharaoh Akhenaten', 'predicate': 2, 'subject': 'Nefertiti'},
#  {'object': 'Ancient Egypt', 'predicate': 4, 'subject': 'Nefertiti'},
#  {'object': 'c. 1370', 'predicate': 31, 'subject': 'Nefertiti'},
#  {'object': 'c. 1330 BC', 'predicate': 31, 'subject': 'Nefertiti'}]
# Answer:
# [{'subject': 'Nefertiti', 'predicate': 2, 'object': 'Pharaoh Akhenaten'}]
# =====================================
# Sample 39: In 1997 the Swissair Group was renamed SAirGroup (although it was again renamed Swissair Group in 2001), with four subdivisions: SAirlines (to which Swissair, regional subsidiaries Crossair and Balair, and leasing subsidiary FlightLease belonged), SAirServices, SAirLogistics, and SAirRelations.
# Response:
# [{'object': 'SAirGroup', 'predicate': 29, 'subject': 'Swissair Group'},
#  {'object': 'Swissair Group', 'predicate': 29, 'subject': 'SAirGroup'},
#  {'object': 'SAirlines', 'predicate': 22, 'subject': 'SAirGroup'},
#  {'object': 'SAirServices', 'predicate': 22, 'subject': 'SAirGroup'},
#  {'object': 'SAirLogistics', 'predicate': 22, 'subject': 'SAirGroup'},
#  {'object': 'SAirRelations', 'predicate': 22, 'subject': 'SAirGroup'}]
# Answer:
# [{'subject': 'Crossair', 'predicate': 13, 'object': 'Swissair'}, {'subject': 'Balair', 'predicate': 13, 'object': 'Swissair'}]
# =====================================
# Sample 40: On 1 April 2002 former regional subsidiary Crossair renamed itself Swiss International Air Lines and took over most of Swissair's routes, planes and staff. Today, Swissair Group still exists and is in the process of being liquidated. Swiss International Air Lines was taken over by the German airline Lufthansa in 2005.
# Response:
# [{'object': '1 April 2002', 'predicate': 31, 'subject': 'Crossair'},
#  {'object': 'Swissair',
#   'predicate': 14,
#   'subject': 'Swiss International Air Lines'},
#  {'object': 'Lufthansa',
#   'predicate': 14,
#   'subject': 'Swiss International Air Lines'},
#  {'object': 'Swiss International Air Lines',
#   'predicate': 30,
#   'subject': 'Swissair Group'}]
# Answer:
# [{'subject': 'Swiss International Air Lines', 'predicate': 29, 'object': 'Swissair'}]
# =====================================
# Sample 41: The Justice League is a team of fictional superheroes appearing in American comic books published by DC Comics. The team was conceived by writer Gardner Fox during the Silver Age of Comic Books as a reimagining of the Golden Age's Justice Society of America. Originally consisting of Superman (Kal-El/Clark Kent), Batman (Bruce Wayne), Wonder Woman (Diana Prince), The Flash (Barry Allen), Green Lantern (Hal Jordan), Aquaman (Arthur Curry) and Martian Manhunter (J'onn J'onzz), they first appeared together as the Justice League of America (JLA) in "The Brave and the Bold" #28 (March 1960).
# Response:
# [{'object': 'The Brave and the Bold',
#   'predicate': 28,
#   'subject': 'Justice League'},
#  {'object': 'DC Comics', 'predicate': 4, 'subject': 'Justice League'},
#  {'object': 'fictional superheroes',
#   'predicate': 14,
#   'subject': 'Justice League'},
#  {'object': 'Golden Age',
#   'predicate': 22,
#   'subject': 'Justice Society of America'}]
# Answer:
# ...
# =====================================
# Sample 430: "Rip Van Winkle" is a short story by the American author Washington Irving, first published in 1819. It follows a Dutch-American villager in colonial America named Rip Van Winkle who meets mysterious Dutchmen, imbibes their liquor and falls asleep in the Catskill Mountains. He awakes 20 years later to a very changed world, having missed the American Revolution.
# Response:
# [{'object': 'Washington Irving', 'predicate': 8, 'subject': 'Rip Van Winkle'},
#  {'object': 'short story', 'predicate': 4, 'subject': 'Rip Van Winkle'},
#  {'object': '1819', 'predicate': 31, 'subject': 'Rip Van Winkle'},
#  {'object': 'colonial America', 'predicate': 22, 'subject': 'Rip Van Winkle'}]
# Answer:
# [{'subject': 'Rip Van Winkle', 'predicate': 8, 'object': 'Washington Irving'}, {'subject': 'Washington Irving', 'predicate': 28, 'object': 'Rip Van Winkle'}]
# =====================================
# Sample 431: Google Pay (stylized as G Pay; formerly Android Pay) is a digital wallet platform and online payment system developed by Google to power in-app, online, and in-person contactless purchases on mobile devices, enabling users to make payments with Android phones, tablets, or watches. Users in the United States and India can also use an iOS device, albeit with limited functionality. In addition to this, the service also supports passes such as coupons, boarding passes, campus ID cards, car keys, event tickets, movie tickets, public transportation tickets, store cards, and loyalty cards.
# Response:
# [{'object': 'digital wallet platform', 'predicate': 4, 'subject': 'Google Pay'},
#  {'object': 'online payment system', 'predicate': 4, 'subject': 'Google Pay'},
#  {'object': 'United States', 'predicate': 3, 'subject': 'Google Pay'},
#  {'object': 'India', 'predicate': 3, 'subject': 'Google Pay'}]
# Answer:
# [{'subject': 'Google Pay', 'predicate': 19, 'object': 'Google'}, {'subject': 'Android', 'predicate': 19, 'object': 'Google'}]
# =====================================
# Sample 432: The conference championships will be played on the weekend of November 20 and the season will conclude on December 4 with the 56th Vanier Cup championship. 27 university teams in Canada are scheduled to play U Sports football, the highest level of amateur Canadian football.
# Response:
# [{'object': 'December 4',
#   'predicate': 31,
#   'subject': '56th Vanier Cup championship'},
#  {'object': 'amateur Canadian football',
#   'predicate': 22,
#   'subject': 'U Sports football'},
#  {'object': 'university teams in Canada', 'predicate': 28, 'subject': '27'}]
# Answer:
# [{'subject': 'U Sports football', 'predicate': 25, 'object': 'Canadian football'}]
# =====================================
# Sample 433: The 2021–22 Liga Primera de Nicaragua season was to be divided into two tournaments, Apertura and Clausura. The season will determine the 77th and 78th champions in the history of the Liga Primera de Nicaragua, the top division of football in Nicaragua. The Apertura tournament is to be played in the second half of 2021, while the Clausura is to be played in the first half of 2022.
# Response:
# [{'object': 'Apertura',
#   'predicate': 22,
#   'subject': '2021–22 Liga Primera de Nicaragua season'},
#  {'object': 'Clausura',
#   'predicate': 22,
#   'subject': '2021–22 Liga Primera de Nicaragua season'},
#  {'object': 'Nicaragua',
#   'predicate': 0,
#   'subject': 'Liga Primera de Nicaragua'}]
# Answer:
# [{'subject': 'Liga Primera de Nicaragua', 'predicate': 25, 'object': 'football'}, {'subject': 'Liga Primera de Nicaragua', 'predicate': 0, 'object': 'Nicaragua'}]
# =====================================
# Sample 434: Didier Delgado Delgado (born 25 July 1992) is a Colombian professional footballer who plays as a right-back for Greek club Ionikos.
# Response:
# [{'object': 'professional footballer',
#   'predicate': 10,
#   'subject': 'Didier Delgado Delgado'},
#  {'object': 'Colombian', 'predicate': 3, 'subject': 'Didier Delgado Delgado'},
#  {'object': 'Ionikos', 'predicate': 18, 'subject': 'Didier Delgado Delgado'},
#  {'object': 'right-back', 'predicate': 10, 'subject': 'Didier Delgado Delgado'}]
# Answer:
# [{'subject': 'Ionikos', 'predicate': 25, 'object': 'footballer'}]
# =====================================
# Sample 435: The Ferrari 488 (Type F142M) is a mid-engine sports car produced by the Italian automobile manufacturer Ferrari. The car replaced the 458, being the first mid-engine Ferrari to use a turbocharged V8 since the F40.
# Response:
# [{'object': 'mid-engine sports car', 'predicate': 4, 'subject': 'Ferrari 488'},
#  {'object': 'Ferrari', 'predicate': 19, 'subject': 'Ferrari 488'},
#  {'object': '458', 'predicate': 16, 'subject': 'Ferrari 488'},
#  {'object': 'F40', 'predicate': 16, 'subject': 'Ferrari 488'}]
# Answer:
# [{'subject': 'Ferrari 488', 'predicate': 4, 'object': 'sports car'}, {'subject': 'Ferrari 488', 'predicate': 19, 'object': 'Ferrari'}, {'subject': 'Ferrari 488', 'predicate': 16, 'object': '458'}, {'subject': 'sports car', 'predicate': 19, 'object': 'Ferrari'}]
# =====================================
# Sample 436: In 1940 the OUN split into two parts. The older, more moderate members supported Andriy Melnyk and the OUN-M, while the younger and more radical members supported Stepan Bandera's OUN-B. After the start of the Axis invasion of the Soviet Union on 22 June 1941 (Operation Barbarossa), the OUN-B in the person of Yaroslav Stetsko declared an independent Ukrainian state on 30 June 1941 in occupied Lviv, while the region was under the control of Nazi Germany, pledging loyalty to Adolf Hitler. In response, the Nazi authorities suppressed the OUN leadership. In October 1942 the OUN-B established the Ukrainian Insurgent Army (UPA). In 1943–1944, in order to pre-empt Polish efforts at re-establishing Poland's pre-war borders, UPA military units carried out large-scale ethnic cleansing against Polish people. Historians estimate that 100,000 Polish civilians were massacred in Volhynia and Eastern Galicia.
# Response:
# [{'object': 'Andriy Melnyk', 'predicate': 24, 'subject': 'OUN'},
#  {'object': 'Stepan Bandera', 'predicate': 24, 'subject': 'OUN'},
#  {'object': 'Yaroslav Stetsko', 'predicate': 31, 'subject': 'OUN-B'},
#  {'object': 'Ukrainian Insurgent Army', 'predicate': 28, 'subject': 'OUN-B'},
#  {'object': 'ethnic cleansing', 'predicate': 25, 'subject': 'UPA'},
#  {'object': '100,000 Polish civilians', 'predicate': 6, 'subject': 'UPA'}]
# Answer:
# [{'subject': 'Operation Barbarossa', 'predicate': 27, 'object': 'Nazi Germany'}]
# =====================================
# Sample 437: The Drina (, ) is a long Balkans river, which forms a large portion of the border between Bosnia and Herzegovina and Serbia. It is the longest tributary of the Sava River and the longest karst river in the Dinaric Alps which belongs to the Danube river watershed. Its name is derived from the Roman name of the river () which in turn is derived from Greek (Ancient Greek: ).
# Response:
# [{'object': 'Bosnia and Herzegovina', 'predicate': 7, 'subject': 'Drina'},
#  {'object': 'Serbia', 'predicate': 7, 'subject': 'Drina'},
#  {'object': 'Sava River', 'predicate': 22, 'subject': 'Drina'},
#  {'object': 'Dinaric Alps', 'predicate': 22, 'subject': 'Drina'},
#  {'object': 'Danube river watershed', 'predicate': 22, 'subject': 'Drina'}]
# Answer:
# [{'subject': 'Drina', 'predicate': 23, 'object': 'Sava River'}, {'subject': 'Balkans', 'predicate': 0, 'object': 'Bosnia and Herzegovina'}, {'subject': 'Balkans', 'predicate': 0, 'object': 'Serbia'}, {'subject': 'Bosnia and Herzegovina', 'predicate': 21, 'object': 'Balkans'}, {'subject': 'Serbia', 'predicate': 21, 'object': 'Balkans'}, {'subject': 'Sava River', 'predicate': 23, 'object': 'Danube'}]
# =====================================
# Sample 438: The Vera C. Rubin Observatory, previously referred to as the Large Synoptic Survey Telescope (LSST), is an astronomical observatory currently under construction in Chile. Its main task will be an astronomical survey, the Legacy Survey of Space and Time (LSST). The Rubin Observatory has a wide-field reflecting telescope with an 8.4-meter primary mirror that will photograph the entire available sky every few nights. The word "" is derived from the Greek words σύν (syn "together") and ὄψις (opsis "view"), and describes observations that give a broad view of a subject at a particular time. The observatory is named for Vera Rubin, an American astronomer who pioneered discoveries about galaxy rotation rates.
# Response:
# [{'object': 'astronomical observatory',
#   'predicate': 4,
#   'subject': 'Vera C. Rubin Observatory'},
#  {'object': 'Chile', 'predicate': 31, 'subject': 'Vera C. Rubin Observatory'},
#  {'object': 'Vera Rubin',
#   'predicate': 11,
#   'subject': 'Vera C. Rubin Observatory'}]
# Answer:
# [{'subject': 'Vera C. Rubin Observatory', 'predicate': 4, 'object': 'reflecting'}, {'subject': 'Vera C. Rubin Observatory', 'predicate': 15, 'object': 'Vera Rubin'}]
# =====================================
# Sample 439: It is located near the Phewa Lake in Pokhara, Gandaki Province, Nepal. Ratna Mandir was built in 1956 by King Mahendra for his wife Ratna, and the palace is spread over 56,468 square meters.
# Response:
# [{'object': 'Gandaki Province', 'predicate': 22, 'subject': 'Ratna Mandir'},
#  {'object': 'King Mahendra', 'predicate': 1, 'subject': 'Ratna Mandir'},
#  {'object': '1956', 'predicate': 31, 'subject': 'Ratna Mandir'}]
# Answer:
# [{'subject': 'King Mahendra', 'predicate': 2, 'object': 'Ratna'}]
# =====================================
# Sample 440: Normal Sheeple is a 2021 book by Irish playwright and author Paul Howard and is the twenty-first novel in the Ross O'Carroll-Kelly series.
# Response:
# [{'object': 'Paul Howard', 'predicate': 8, 'subject': 'Normal Sheeple'},
#  {'object': "Ross O'Carroll-Kelly",
#   'predicate': 4,
#   'subject': 'Normal Sheeple'}]
# Answer:
# [{'subject': 'Paul Howard', 'predicate': 28, 'object': "Ross O'Carroll-Kelly"}, {'subject': "Ross O'Carroll-Kelly", 'predicate': 8, 'object': 'Paul Howard'}]
# =====================================
# Sample 441: Stanley Briggs (7 February 1872 – 1931) was an English footballer who played for Folkestone, Tottenham Hotspur and Woolwich Arsenal.
# Response:
# [{'object': 'footballer', 'predicate': 10, 'subject': 'Stanley Briggs'},
#  {'object': 'Folkestone', 'predicate': 18, 'subject': 'Stanley Briggs'},
#  {'object': 'Tottenham Hotspur', 'predicate': 18, 'subject': 'Stanley Briggs'},
#  {'object': 'Woolwich Arsenal', 'predicate': 18, 'subject': 'Stanley Briggs'}]
# Answer:
# [{'subject': 'Folkestone', 'predicate': 25, 'object': 'footballer'}, {'subject': 'Tottenham Hotspur', 'predicate': 25, 'object': 'footballer'}, {'subject': 'Woolwich Arsenal', 'predicate': 25, 'object': 'footballer'}]
# =====================================
# Sample 442: Despite being technologically inferior to its fourth-generation competitors (Sega's Game Gear, Atari's Lynx, and NEC's TurboExpress), the Game Boy received praise for its battery life and durability in its construction. It quickly outsold the competition, selling one million units in the United States within a few weeks. An estimated 118 million units of the Game Boy and its successor, the Game Boy Color, have been sold worldwide, making it the third best-selling video game console of all time. It is one of the most recognizable devices from the 1990s, becoming a cultural icon in the years following its release. Several redesigns were released during the console's lifetime, including the Game Boy Pocket in 1996 and the Game Boy Light in 1998 (Japan only). Production of the Game Boy continued into the early 2000s, even after the release of its second successor, the Game Boy Advance, in 2001. Production ceased in 2003.
# Response:
# [{'object': 'third best-selling video game console',
#   'predicate': 14,
#   'subject': 'Game Boy'},
#  {'object': '1990s', 'predicate': 31, 'subject': 'Game Boy'},
#  {'object': '1996', 'predicate': 31, 'subject': 'Game Boy Pocket'},
#  {'object': '1998', 'predicate': 31, 'subject': 'Game Boy Light'},
#  {'object': '2001', 'predicate': 31, 'subject': 'Game Boy Advance'}]
# Answer:
# [{'subject': 'Game Gear', 'predicate': 22, 'object': 'fourth-generation'}, {'subject': 'Game Gear', 'predicate': 19, 'object': 'Sega'}, {'subject': 'Lynx', 'predicate': 22, 'object': 'fourth-generation'}, {'subject': 'Lynx', 'predicate': 19, 'object': 'Atari'}, {'subject': 'TurboExpress', 'predicate': 22, 'object': 'fourth-generation'}, {'subject': 'TurboExpress', 'predicate': 19, 'object': 'NEC'}, {'subject': 'Game Boy', 'predicate': 22, 'object': 'fourth-generation'}, {'subject': 'Game Boy Color', 'predicate': 16, 'object': 'Game Boy'}]
# =====================================
# Sample 443: GNU IceCat, formerly known as GNU IceWeasel, is a completely free and open-source version of the Mozilla Firefox web browser distributed by the GNU Project. It is compatible with Linux, Windows, Android and macOS.
# Response:
# [{'object': 'open-source', 'predicate': 14, 'subject': 'GNU IceCat'},
#  {'object': 'Mozilla Firefox', 'predicate': 4, 'subject': 'GNU IceCat'},
#  {'object': 'GNU Project', 'predicate': 22, 'subject': 'GNU IceCat'}]
# Answer:
# [{'subject': 'GNU IceCat', 'predicate': 4, 'object': 'web browser'}, {'subject': 'GNU IceCat', 'predicate': 19, 'object': 'GNU Project'}, {'subject': 'Mozilla Firefox', 'predicate': 4, 'object': 'web browser'}]
# =====================================
# Sample 444: Dracula Untold is a 2014 American dark fantasy action film directed by Gary Shore in his feature film debut and written by Matt Sazama and Burk Sharpless. A reboot of the "Dracula" film series, the plot creates an origin story for the titular character, rather than using the storyline of Bram Stoker's 1897 novel. In this adaptation, Dracula is the monster alter ego of historical figure Vlad III "the Impaler" Drăculea. Luke Evans portrays the title character, with Sarah Gadon, Dominic Cooper, Art Parkinson, and Charles Dance cast in supporting roles. Principal photography began in Northern Ireland on August 5, 2013.
# Response:
# [{'object': 'Gary Shore', 'predicate': 9, 'subject': 'Dracula Untold'},
#  {'object': 'Luke Evans', 'predicate': 18, 'subject': 'Dracula Untold'},
#  {'object': 'Sarah Gadon', 'predicate': 18, 'subject': 'Dracula Untold'},
#  {'object': 'Dominic Cooper', 'predicate': 18, 'subject': 'Dracula Untold'},
#  {'object': 'Art Parkinson', 'predicate': 18, 'subject': 'Dracula Untold'},
#  {'object': 'Charles Dance', 'predicate': 18, 'subject': 'Dracula Untold'}]
# Answer:
# [{'subject': 'Dracula Untold', 'predicate': 14, 'object': 'action film'}, {'subject': 'Dracula Untold', 'predicate': 9, 'object': 'Gary Shore'}, {'subject': 'Bram Stoker', 'predicate': 28, 'object': '1897 novel'}, {'subject': '1897 novel', 'predicate': 8, 'object': 'Bram Stoker'}]
# =====================================
# Sample 445: Located on the Brunswick Peninsula north of the Strait of Magellan, Punta Arenas was originally established by the Chilean government in 1848 as a tiny penal colony to assert sovereignty over the Strait. During the remainder of the 1800s, Punta Arenas grew in size and importance due to the increasing maritime traffic and trade travelling to the west coasts of South and North America. This period of growth also resulted from the waves of European immigrants, mainly from Croatia and Russia attracted to the gold rush and sheep farming boom in the 1880s and early 1900s. The largest sheep company, controlling 10,000 square kilometres in Chile and Argentina, was based in Punta Arenas, and its owners lived there.
# Response:
# [{'object': 'Brunswick Peninsula', 'predicate': 22, 'subject': 'Punta Arenas'},
#  {'object': 'Strait of Magellan', 'predicate': 22, 'subject': 'Punta Arenas'},
#  {'object': 'Chilean government', 'predicate': 11, 'subject': 'Punta Arenas'},
#  {'object': 'Chile', 'predicate': 0, 'subject': 'Punta Arenas'},
#  {'object': 'Argentina', 'predicate': 0, 'subject': 'Punta Arenas'}]
# Answer:
# [{'subject': 'Brunswick Peninsula', 'predicate': 20, 'object': 'Strait of Magellan'}]
# =====================================

# %%
entity_type_set = set()
for sample in redfm_test_set:
    entity_types = [e['type'] for e in sample['entities']]
    entity_type_set.update(entity_types)
print(entity_type_set)
# Out:
# {'EVE', 'ORG', 'NUMBER', 'DATE', 'TIME', 'PER', 'CEL', 'Concept', 'MEDIA', 'LOC', 'MISC', 'UNK'}
